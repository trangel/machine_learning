# %% [markdown]
# # Freedom exploration
#
# 1. [Data exploration](#data_exploration)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
filename='TABLE_III._Deaths_in_122_U.S._cities.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   Reporting Area  MMWR YEAR  MMWR WEEK  \
# 0    New England       2016          1
# 1  Mid. Atlantic       2016          1
# 2   E.N. Central       2016          1
# 3   W.N. Central       2016          1
# 4    S. Atlantic       2016          1
#
#    All causes, by age (years), All Ages**  \
# 0                                   600.0
# 1                                   807.0
# 2                                  2468.0
# 3                                   634.0
# 4                                  1402.0
#
#   All causes, by age (years), All Ages**, flag  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    All causes, by age (years), >=65 All causes, by age (years), >=65, flag  \
# 0                             426.0                                    NaN
# 1                             563.0                                    NaN
# 2                            1611.0                                    NaN
# 3                             432.0                                    NaN
# 4                             893.0                                    NaN
#
#    All causes, by age (years), 45-64 All causes, by age (years), 45-64, flag  \
# 0                              125.0                                     NaN
# 1                              181.0                                     NaN
# 2                              594.0                                     NaN
# 3                              150.0                                     NaN
# 4                              343.0                                     NaN
#
#    All causes, by age (years), 25-44 All causes, by age (years), 25-44, flag  \
# 0                               28.0                                     NaN
# 1                               32.0                                     NaN
# 2                              167.0                                     NaN
# 3                               31.0                                     NaN
# 4                               92.0                                     NaN
#
#    All causes, by age (years), 1-24 All causes, by age (years), 1-24, flag  \
# 0                              12.0                                    NaN
# 1                              13.0                                    NaN
# 2                              62.0                                    NaN
# 3                               9.0                                    NaN
# 4                              32.0                                    NaN
#
#    All causes, by age (years), LT 1 All causes, by age (years), LT 1, flag  \
# 0                               9.0                                    NaN
# 1                              18.0                                    NaN
# 2                              34.0                                    NaN
# 3                              11.0                                    NaN
# 4                              41.0                                    NaN
#
#    P&I Total P&I Total, flag Location 1  Location 2
# 0       47.0             NaN        NaN         NaN
# 1       32.0             NaN        NaN         NaN
# 2      159.0             NaN        NaN         NaN
# 3       37.0             NaN        NaN         NaN
# 4       88.0             NaN        NaN         NaN

# %% [markdown]
# <a id='data_exploration'></a>
# ## Data exploration

# %%
df.describe()
# Out:
#        MMWR YEAR    MMWR WEEK  All causes, by age (years), All Ages**  \
# count     5148.0  5148.000000                             4830.000000
# mean      2016.0    20.000000                              279.840373
# std          0.0    11.255722                             1080.741649
# min       2016.0     1.000000                                1.000000
# 25%       2016.0    10.000000                               39.000000
# 50%       2016.0    20.000000                               77.000000
# 75%       2016.0    30.000000                              154.000000
# max       2016.0    39.000000                            12883.000000
#
#        All causes, by age (years), >=65  All causes, by age (years), 45-64  \
# count                       4824.000000                        4778.000000
# mean                         187.677861                          65.104018
# std                          725.465670                         249.953888
# min                            1.000000                           1.000000
# 25%                           27.000000                           8.000000
# 50%                           52.000000                          18.000000
# 75%                          102.000000                          37.000000
# max                         8816.000000                        2963.000000
#
#        All causes, by age (years), 25-44  All causes, by age (years), 1-24  \
# count                        4358.000000                       3301.000000
# mean                           19.521340                          8.449258
# std                            71.385536                         26.659848
# min                             1.000000                          1.000000
# 25%                             2.000000                          1.000000
# 50%                             5.000000                          3.000000
# 75%                            12.000000                          5.000000
# max                           880.000000                        276.000000
#
#        All causes, by age (years), LT 1    P&I Total  Location 2
# count                       3005.000000  4299.000000         0.0
# mean                           7.186023    19.817865         NaN
# std                           21.626929    73.040133         NaN
# min                            1.000000     1.000000         NaN
# 25%                            1.000000     3.000000         NaN
# 50%                            2.000000     6.000000         NaN
# 75%                            5.000000    12.000000         NaN
# max                          226.000000   936.000000         NaN

# %% [markdown]
# We are dealing with many NaN values, but its not clear how to treat them all.
# I will take the NaNs into account afterwards.

# %% [markdown]
# <a id='deaths_per_area'></a>
# ## Deaths per reporting area (all ages)

# %%
# Get a subsample of the dataset with deaths for all ages
# Do the report only for 2016 for simplicity
df_2016 = df[df['MMWR YEAR']==2016]
death_per_area = df_2016[['Reporting Area','All causes, by age (years), All Ages**']]
death_per_area.head()
death_per_area.columns=['Reporting Area','Deaths']

# 2. Drop NaNs:
print(len(death_per_area))
death_per_area = death_per_area.dropna()
print(len(death_per_area))
# Out:
# 5148
# 4830

# %% [raw]
# #This plot is too time consuming
# # Initialize the matplotlib figure
# #f, ax = plt.pyplot.subplots(figsize=(15, 6))
#
# #Set context, increase font size
# sns.set_context("poster", font_scale=1.5)
# #Create a figure
# plt.pyplot.figure(figsize=(15, 4))
# #Define the axis object
# ax = sns.barplot(x=death_per_area['Reporting Area'], y=death_per_area['Deaths'], hue='Reporting Area', data=death_per_area, palette="Blues_d")
# #set parameters
# ax.set(xlabel='Reporting Area', ylabel='Number of deaths', title= "Deaths per area")
# #show the plot
# sns.plt.show()

# %%
df.mean()
# Out:
# MMWR YEAR                                 2016.000000
# MMWR WEEK                                   20.000000
# All causes, by age (years), All Ages**     279.840373
# All causes, by age (years), >=65           187.677861
# All causes, by age (years), 45-64           65.104018
# All causes, by age (years), 25-44           19.521340
# All causes, by age (years), 1-24             8.449258
# All causes, by age (years), LT 1             7.186023
# P&I Total                                   19.817865
# Location 2                                        NaN
# dtype: float64

# %%
means=df.mean().values[3:8]
categories=['>=65','45-64','25-44','1-24','LT-1']
categories_ids=[1,2,3,4,5]
means
# Out:
# array([ 187.6778607 ,   65.10401842,   19.52134006,    8.4492578 ,
#           7.18602329])

# %%
# Initialize the matplotlib figure
#f, ax = plt.pyplot.subplots(figsize=(15, 6))

#Set context, increase font size
sns.set_context("poster", font_scale=1.5)
#Create a figure
plt.pyplot.figure(figsize=(15, 4))
#Define the axis object
ax = sns.barplot(x=categories, y=means,  palette="Blues_d")
#set parameters
ax.set(xlabel='Age category', ylabel='Deaths mean', title= "Deaths per age category")
#show the plot
sns.plt.show()

# %% [markdown]
# This plot shows the number of deaths per age category. As expected the number of deaths increases with age.
